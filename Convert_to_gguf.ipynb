# %%
# !pip uninstall -y torch torchvision torchaudio triton torchao
# !pip install --index-url https://download.pytorch.org/whl/cu121 torch torchvision torchaudio
# Out:
# Found existing installation: torch 2.9.0+cu126
# Uninstalling torch-2.9.0+cu126:
#   Successfully uninstalled torch-2.9.0+cu126
# Found existing installation: torchvision 0.24.0+cu126
# Uninstalling torchvision-0.24.0+cu126:
#   Successfully uninstalled torchvision-0.24.0+cu126
# Found existing installation: torchaudio 2.9.0+cu126
# Uninstalling torchaudio-2.9.0+cu126:
#   Successfully uninstalled torchaudio-2.9.0+cu126
# Found existing installation: triton 3.5.0
# Uninstalling triton-3.5.0:
#   Successfully uninstalled triton-3.5.0
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 MB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 121.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 105.9 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/ggerganov/llama.cpp.git
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 70053, done.
# remote: Counting objects: 100% (271/271), done.
# remote: Compressing objects: 100% (172/172), done.
# remote: Total 70053 (delta 159), reused 102 (delta 99), pack-reused 69782 (from 2)
# Receiving objects: 100% (70053/70053), 214.54 MiB | 26.39 MiB/s, done.
# Resolving deltas: 100% (50637/50637), done.

# %%
# !pip install -r llama.cpp/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/nightly, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/nightly, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/nightly
# Ignoring torch: markers 'platform_machine == "s390x"' don't match your environment
# Ignoring torch: markers 'platform_machine == "s390x"' don't match your environment
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 129.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 123.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 12.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -q -r llama.cpp/requirements/requirements-convert_hf_to_gguf.txt
# !pip install -q -r llama.cpp/requirements/requirements-convert_hf_to_gguf_update.txt

# %%
# !pip install peft
# !pip install transformers

# %%
# !pip install -q bitsandbytes transformers peft accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 15.4 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall -y transformers peft
# !pip install -q "transformers==4.46.3" "peft==0.12.0" "accelerate>=0.33.0" safetensors
# Out:
# Found existing installation: transformers 4.57.2
# Uninstalling transformers-4.57.2:
#   Successfully uninstalled transformers-4.57.2
# Found existing installation: peft 0.18.0
# Uninstalling peft-0.18.0:
#   Successfully uninstalled peft-0.18.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 94.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 25.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 108.6 MB/s eta 0:00:00

# %%
# !pip install -U transformers sentencepiece accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 93.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 81.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.3
#     Uninstalling transformers-4.46.3:
#       Successfully uninstalled transformers-4.46.3
# ...

# %%
# !python llama.cpp/convert_hf_to_gguf.py /content/drive/MyDrive/code_model_v2 \
  --outfile /content/drive/MyDrive/merged_fp16_code.gguf \
  --outtype q8_0
# Out:
# INFO:hf-to-gguf:Loading model: code_model_v2
# INFO:hf-to-gguf:Model architecture: LlamaForCausalLM
# INFO:hf-to-gguf:gguf: indexing model part 'model.safetensors'
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:rope_freqs.weight,           torch.float32 --> F32, shape = {32}
# INFO:hf-to-gguf:token_embd.weight,           torch.bfloat16 --> Q8_0, shape = {2048, 128256}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,      torch.bfloat16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,       torch.bfloat16 --> Q8_0, shape = {8192, 2048}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,       torch.bfloat16 --> Q8_0, shape = {2048, 8192}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,         torch.bfloat16 --> Q8_0, shape = {2048, 8192}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {2048}
# INFO:hf-to-gguf:blk.0.attn_k.weight,         torch.bfloat16 --> Q8_0, shape = {2048, 512}
# ...
