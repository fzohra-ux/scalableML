# %% [markdown]
# <a href="https://colab.research.google.com/github/fzohra-ux/scalableML/blob/main/Upload_to_huging_face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q huggingface_hub

# %%
from huggingface_hub import notebook_login
notebook_login(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)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from huggingface_hub import create_repo

repo_name = "llama-3.2-1b-merged-code-gguf-v2"
create_repo(repo_id=repo_name, repo_type="model", exist_ok=True)
# Out:
# RepoUrl('https://huggingface.co/FatimaZh/llama-3.2-1b-merged-code-gguf-v2', endpoint='https://huggingface.co', repo_type='model', repo_id='FatimaZh/llama-3.2-1b-merged-code-gguf-v2')

# %%
from huggingface_hub import upload_file

upload_file(
    path_or_fileobj="/content/drive/MyDrive/merged_fp16_code.gguf",
    path_in_repo="merged_fp16_code_v2.gguf",
    repo_id='FatimaZh/llama-3.2-1b-merged-code-gguf-v2',
    repo_type="model",
)
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...ive/merged_fp16_code.gguf:   0%|          |  559kB / 1.32GB
# CommitInfo(commit_url='https://huggingface.co/FatimaZh/llama-3.2-1b-merged-code-gguf-v2/commit/3d473a053631e4e89ae93899c3659f603c7a6158', commit_message='Upload merged_fp16_code_v2.gguf with huggingface_hub', commit_description='', oid='3d473a053631e4e89ae93899c3659f603c7a6158', pr_url=None, repo_url=RepoUrl('https://huggingface.co/FatimaZh/llama-3.2-1b-merged-code-gguf-v2', endpoint='https://huggingface.co', repo_type='model', repo_id='FatimaZh/llama-3.2-1b-merged-code-gguf-v2'), pr_revision=None, pr_num=None)
